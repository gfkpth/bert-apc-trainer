# %% [markdown]
# # Overview
#
# This notebook provides an overview of the available data

# %% [markdown]
# # Preamble

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_colwidth', None)

# %%
dwds = pd.read_csv('../data/copyright/DWDS_APC_main.csv',index_col='ID')
# Out:
# /tmp/ipykernel_13717/4155953049.py:1: DtypeWarning: Columns (14,18,20,24,26,27,28,33,34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   dwds = pd.read_csv('../data/copyright/DWDS_APC_main.csv',index_col='ID')

# %%
dwds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45539 entries, 0 to 45538
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Search          45538 non-null  object
#  1   No.             45539 non-null  object
#  2   Date            45539 non-null  object
#  3   Genre           45539 non-null  object
#  4   Bibl            45539 non-null  object
#  5   ContextBefore   45329 non-null  object
#  6   Hit             45539 non-null  object
#  7   ContextAfter    45223 non-null  object
#  8   incl            45539 non-null  float64
#  9   APC             6493 non-null   object
#  10  Pron            6512 non-null   object
#  11  N               6513 non-null   object
#  12  Nlemma          6504 non-null   object
#  13  doubled         82 non-null     object
#  14  comment         711 non-null    object
#  15  Nprops          1412 non-null   object
#  16  GenderA         268 non-null    object
#  17  StrengthA       175 non-null    object
#  18  NumNDiff        32 non-null     float64
#  19  Person          45539 non-null  object
#  20  Number          41023 non-null  object
#  21  Case            6451 non-null   object
#  22  PostN           525 non-null    object
#  23  PostN-weight    521 non-null    object
#  24  PostN-cat       517 non-null    object
#  25  Poss            8 non-null      object
#  26  PossPN          6 non-null      object
#  27  AdjPre          45525 non-null  object
#  28  AdjPre1         1351 non-null   object
#  29  AdjPre2         52 non-null     object
#  30  AdjPost         33 non-null     float64
#  31  AdjPost1        33 non-null     object
#  32  AdjPost2        1 non-null      object
#  33  AdjModStrength  1 non-null      object
#  34  Quant           158 non-null    object
#  35  QuantPos        157 non-null    object
#  36  PreN-other      16 non-null     object
#  37  PreN-weight     1484 non-null   float64
#  38  ClauseType      6438 non-null   object
#  39  VerbPos         5259 non-null   object
#  40  Func            6443 non-null   object
#  41  Position        5226 non-null   object
# dtypes: float64(4), object(38)
# memory usage: 14.9+ MB

# %%
dwds.head().T
# Out:
# ID                                                                                                       0  \
# Search                                                                                           ich $p=N*
# No.                                                                                                      1
# Date                                                                                            1959-12-31
# Genre                                                                                         Belletristik
# Bibl                                  Strittmatter, Erwin: Pony Pedro, Berlin: Kinderbuchverl. 1959, S. 11
# ContextBefore                                         Und es war das erste Mal, daß ich für mein Pony log.
# Hit                                                                       ALS ICH PEDRO ZUM ERSTEN MAL SAH
# ContextAfter    Auf dem Hofe des Ponyverkäufers kreischte eine Kreissäge, eine Hobelmaschine seufzte dazu.
# incl                                                                                                   0.0
# APC                                                                                                    NaN
# Pron                                                                                                   NaN
# N                                                                                                      NaN
# Nlemma                                                                                                 NaN
# doubled                                                                                                NaN
# comment                                                                                                NaN
# Nprops                                                                                                 NaN
# GenderA                                                                                                NaN
# StrengthA                                                                                              NaN
# NumNDiff                                                                                               NaN
# Person                                                                                                   1
# Number                                                                                                  sg
# Case                                                                                                   NaN
# PostN                                                                                                  NaN
# PostN-weight                                                                                           NaN
# PostN-cat                                                                                              NaN
# Poss                                                                                                   NaN
# PossPN                                                                                                 NaN
# AdjPre                                                                                                 0.0
# AdjPre1                                                                                                NaN
# AdjPre2                                                                                                NaN
# AdjPost                                                                                                NaN
# AdjPost1                                                                                               NaN
# AdjPost2                                                                                               NaN
# AdjModStrength                                                                                         NaN
# Quant                                                                                                  NaN
# QuantPos                                                                                               NaN
# PreN-other                                                                                             NaN
# PreN-weight                                                                                            NaN
# ClauseType                                                                                             NaN
# VerbPos                                                                                                NaN
# Func                                                                                                   NaN
# Position                                                                                               NaN
#
# ID                                                                                 1  \
# Search                                                                     ich $p=N*
# No.                                                                                2
# Date                                                                      1959-12-31
# Genre                                                                   Belletristik
# Bibl            Strittmatter, Erwin: Pony Pedro, Berlin: Kinderbuchverl. 1959, S. 27
# ContextBefore                                           Wir hatten Eindruck gemacht.
# Hit                                                WESHALB ICH BLUMEN BEZAHLENMUSSTE
# ContextAfter                                                 Die Sonne ging rot auf.
# incl                                                                             0.0
# APC                                                                              NaN
# Pron                                                                             NaN
# N                                                                                NaN
# Nlemma                                                                           NaN
# doubled                                                                          NaN
# comment                                                                          NaN
# Nprops                                                                           NaN
# GenderA                                                                          NaN
# StrengthA                                                                        NaN
# NumNDiff                                                                         NaN
# Person                                                                             1
# Number                                                                            sg
# Case                                                                             NaN
# PostN                                                                            NaN
# PostN-weight                                                                     NaN
# PostN-cat                                                                        NaN
# Poss                                                                             NaN
# PossPN                                                                           NaN
# AdjPre                                                                           0.0
# AdjPre1                                                                          NaN
# AdjPre2                                                                          NaN
# AdjPost                                                                          NaN
# AdjPost1                                                                         NaN
# AdjPost2                                                                         NaN
# AdjModStrength                                                                   NaN
# Quant                                                                            NaN
# QuantPos                                                                         NaN
# PreN-other                                                                       NaN
# PreN-weight                                                                      NaN
# ClauseType                                                                       NaN
# VerbPos                                                                          NaN
# Func                                                                             NaN
# Position                                                                         NaN
#
# ID                                                                                                                                                                                  2  \
# Search                                                                                                                                                                      ich $p=N*
# No.                                                                                                                                                                                 3
# Date                                                                                                                                                                       1959-12-31
# Genre                                                                                                                                                                    Belletristik
# Bibl                                                                                                            Strittmatter, Erwin: Pony Pedro, Berlin: Kinderbuchverl. 1959, S. 150
# ContextBefore                                                                                                                  Wieder zieht mich das Leben in sein gesundes Getümmel.
# Hit                                                                                                                                              WAS ICH BEI EINEM HENGSTKAMPF LERNTE
# ContextAfter    Auf unserem Kiesberg, wo die Hungerblumen mit gelben Augen in den blauen Himmel schaun und der silbergraue Schafschwingel still vor sich hin wächst, ist Axels Reich.
# incl                                                                                                                                                                              0.0
# APC                                                                                                                                                                               NaN
# Pron                                                                                                                                                                              NaN
# N                                                                                                                                                                                 NaN
# Nlemma                                                                                                                                                                            NaN
# doubled                                                                                                                                                                           NaN
# comment                                                                                                                                                                           NaN
# Nprops                                                                                                                                                                            NaN
# GenderA                                                                                                                                                                           NaN
# StrengthA                                                                                                                                                                         NaN
# NumNDiff                                                                                                                                                                          NaN
# Person                                                                                                                                                                              1
# Number                                                                                                                                                                             sg
# Case                                                                                                                                                                              NaN
# PostN                                                                                                                                                                             NaN
# PostN-weight                                                                                                                                                                      NaN
# PostN-cat                                                                                                                                                                         NaN
# Poss                                                                                                                                                                              NaN
# PossPN                                                                                                                                                                            NaN
# AdjPre                                                                                                                                                                            0.0
# AdjPre1                                                                                                                                                                           NaN
# AdjPre2                                                                                                                                                                           NaN
# AdjPost                                                                                                                                                                           NaN
# AdjPost1                                                                                                                                                                          NaN
# AdjPost2                                                                                                                                                                          NaN
# AdjModStrength                                                                                                                                                                    NaN
# Quant                                                                                                                                                                             NaN
# QuantPos                                                                                                                                                                          NaN
# PreN-other                                                                                                                                                                        NaN
# PreN-weight                                                                                                                                                                       NaN
# ClauseType                                                                                                                                                                        NaN
# VerbPos                                                                                                                                                                           NaN
# Func                                                                                                                                                                              NaN
# Position                                                                                                                                                                          NaN
#
# ID                                                                                                                                                                         3  \
# Search                                                                                                                                                             ich $p=N*
# No.                                                                                                                                                                        4
# Date                                                                                                                                                              1999-02-15
# Genre                                                                                                                                                           Belletristik
# Bibl                                                                                                                                                  Salbader, 1999, Nr. 24
# ContextBefore                                                                                                                                                            NaN
# Hit                                                                                                                                              ICH SCHEISS AUF DRAG-QUEENS
# ContextAfter    Für jeden ständigen Homo kommt einmal der Zeitpunkt, wo er sich entscheiden muß, Tunte zu werden oder weiterhin als Dorfschwuler durch die Gegend zu laufen.
# incl                                                                                                                                                                     0.0
# APC                                                                                                                                                                      NaN
# Pron                                                                                                                                                                     NaN
# N                                                                                                                                                                        NaN
# Nlemma                                                                                                                                                                   NaN
# doubled                                                                                                                                                                  NaN
# comment                                                                                                                                                                  NaN
# Nprops                                                                                                                                                                   NaN
# GenderA                                                                                                                                                                  NaN
# StrengthA                                                                                                                                                                NaN
# NumNDiff                                                                                                                                                                 NaN
# Person                                                                                                                                                                     1
# Number                                                                                                                                                                    sg
# Case                                                                                                                                                                     NaN
# PostN                                                                                                                                                                    NaN
# PostN-weight                                                                                                                                                             NaN
# PostN-cat                                                                                                                                                                NaN
# Poss                                                                                                                                                                     NaN
# PossPN                                                                                                                                                                   NaN
# AdjPre                                                                                                                                                                   0.0
# AdjPre1                                                                                                                                                                  NaN
# AdjPre2                                                                                                                                                                  NaN
# AdjPost                                                                                                                                                                  NaN
# AdjPost1                                                                                                                                                                 NaN
# AdjPost2                                                                                                                                                                 NaN
# AdjModStrength                                                                                                                                                           NaN
# Quant                                                                                                                                                                    NaN
# QuantPos                                                                                                                                                                 NaN
# PreN-other                                                                                                                                                               NaN
# PreN-weight                                                                                                                                                              NaN
# ClauseType                                                                                                                                                               NaN
# VerbPos                                                                                                                                                                  NaN
# Func                                                                                                                                                                     NaN
# Position                                                                                                                                                                 NaN
#
# ID                                                                                                                                                  4
# Search                                                                                                                                      ich $p=N*
# No.                                                                                                                                                 5
# Date                                                                                                                                       1900-10-27
# Genre                                                                                                                                    Belletristik
# Bibl            Brief von Wilhelm Busch an Johanna Keßler vom 27.10.1900. In: ders., Gesammelte Werke, Berlin: Directmedia Publ. 2002 [1900], S. 5353
# ContextBefore                                                                                                                          Liebste Tante!
# Hit               Ich gratulire zum Urenkelchen No 2. - Zunächst, scheint's, braucht man nicht bange zu sein, daß das Menschengeschlecht alle wird. -
# ContextAfter                                                                       Auch bei uns hier wird demnächst ein Zuwachs der Familie erwartet.
# incl                                                                                                                                              0.0
# APC                                                                                                                                               NaN
# Pron                                                                                                                                              NaN
# N                                                                                                                                                 NaN
# Nlemma                                                                                                                                            NaN
# doubled                                                                                                                                           NaN
# comment                                                                                                                                           NaN
# Nprops                                                                                                                                            NaN
# GenderA                                                                                                                                           NaN
# StrengthA                                                                                                                                         NaN
# NumNDiff                                                                                                                                          NaN
# Person                                                                                                                                              1
# Number                                                                                                                                             sg
# Case                                                                                                                                              NaN
# PostN                                                                                                                                             NaN
# PostN-weight                                                                                                                                      NaN
# PostN-cat                                                                                                                                         NaN
# Poss                                                                                                                                              NaN
# PossPN                                                                                                                                            NaN
# AdjPre                                                                                                                                            0.0
# AdjPre1                                                                                                                                           NaN
# AdjPre2                                                                                                                                           NaN
# AdjPost                                                                                                                                           NaN
# AdjPost1                                                                                                                                          NaN
# AdjPost2                                                                                                                                          NaN
# AdjModStrength                                                                                                                                    NaN
# Quant                                                                                                                                             NaN
# QuantPos                                                                                                                                          NaN
# PreN-other                                                                                                                                        NaN
# PreN-weight                                                                                                                                       NaN
# ClauseType                                                                                                                                        NaN
# VerbPos                                                                                                                                           NaN
# Func                                                                                                                                              NaN
# Position                                                                                                                                          NaN

# %%
dwds.describe()
# Out:
#                incl  NumNDiff    AdjPost  PreN-weight
# count  45539.000000      32.0  33.000000  1484.000000
# mean       0.213202       1.0   1.030303     1.060647
# std        0.755716       0.0   0.174078     0.329021
# min        0.000000       1.0   1.000000     1.000000
# 25%        0.000000       1.0   1.000000     1.000000
# 50%        0.000000       1.0   1.000000     1.000000
# 75%        0.000000       1.0   1.000000     1.000000
# max        7.000000       1.0   2.000000     9.000000

# %% [markdown]
# *Overview of annotation codes*
#
# 0
# :   no APC
#
# 1
# :   APC
#
# 2
# :   unclear (all cases cleared up here)
#
# 3
# :   cases of coordination (lines doubled to retain each lemma)
#
# 4
# :   sentences that appear to be doubled in list (i.e. identical quote with identical source identification found elswhere)
#
# 5
# :   pronouns in combination with quantifier or number (e.g. *wir vier* 'the four of us', *wir beide* 'us two')
#
# 6
# :   possible cases of (close?) apposition, typically involving proper name
#
# 7
# :   cases of APCs (=1) that raised questions for further manual coding (not relevant here)

# %%
dwds.incl.unique()
# Out:
# array([0., 1., 6., 3., 4., 7., 5.])

# %%
dwds.value_counts('incl')
# Out:
# incl
# 0.0    38912
# 1.0     5950
# 7.0      238
# 5.0      220
# 6.0      107
# 3.0       97
# 4.0       15
# Name: count, dtype: int64

# %%
sns.countplot(dwds, x='incl')
# Out:
# <Axes: xlabel='incl', ylabel='count'>

# %%
dwds.loc[dwds.incl==3, ['Hit','APC']].head()
# Out:
#                                                                                                                                                                                                                                                    Hit  \
# ID
# 119                                                                                                                                                                     »Ich irrdisches Geschöpff und Schertz der Sterblichkeit«, schreibt Lohenstein.
# 6994   Das geschah für dich, du Unbewußter, dachte er, und für mich Denkenden, Fühlenden und Ringenden gab's nur ein Erblühen, für meinen Schaffenstrieb nur eine unter den Stacheln der Werdensqual entstandene, in Qualen wieder vernichtete Frucht.
# 6995   Das geschah für dich, du Unbewußter, dachte er, und für mich Denkenden, Fühlenden und Ringenden gab's nur ein Erblühen, für meinen Schaffenstrieb nur eine unter den Stacheln der Werdensqual entstandene, in Qualen wieder vernichtete Frucht.
# 11718                                                                                                (A. Mangelsdorff und die Big Band des belg. Rundfunks); Ich armes Mädchen und Motherless Child (J.-Fr.Oktett mit A. Mangelsdorff und Gerd Dudek).
# 13532    Es war sehr komisch, wie ich da als Prüfling saß, ich ordentlicher Professor und Senator der TH, der ich 1914 mit dem Kolloquium mein letztes Examen gemacht zu haben glaubte und in den folgenden zwanzig Jahren so oft selber geprüft habe.
#
#                                                           APC
# ID
# 119    ich irrdisches Geschöpff und Schertz der Sterblichkeit
# 6994                  mich Denkenden, Fühlenden und Ringenden
# 6995                  mich Denkenden, Fühlenden und Ringenden
# 11718                  ich armes Mädchen und Motherless Child
# 13532           ich ordentlicher Professor und Senator der TH

# %% [markdown]
# Action plan:
#
# - delete rows with incl==4: removing doubles
# - columns with incl==3 can also be deleted: as the full APC string should be retained in the 'APC' column, so these are just doubles for current purposes
# - set incl==6 to 0: we're not going to deal with appositives here and annotations are a bit iffy for this category anyway
# - set incl==7 to 1: these were originally 1s, with questions raised for an annotation step that does not concern us here (and may be abandoned anyway)
#
# **target-related decision regarding incl==5**
# - set rows with incl==5 to incl==0 because if we don't want to consider expressions like *wir vier*

# %%
dwds = dwds[~dwds.incl.isin([3, 4])]

# %%
dwds.loc[dwds.incl.isin([5,6]),'incl'] = 0

# %%
dwds.loc[dwds.incl == 7,'incl'] = 1

# %% [markdown]
# ## Value checks
#
# Check for NaN values overall first.

# %%
dwds.isna().sum()
# Out:
# Search                0
# No.                   0
# Date                  0
# Genre                 0
# Bibl                  0
# ContextBefore       209
# Hit                   0
# ContextAfter        316
# incl                  0
# APC               39038
# Pron              39019
# N                 39018
# Nlemma            39027
# doubled           45347
# comment           44738
# Nprops            44035
# GenderA           45164
# StrengthA         45258
# NumNDiff          45395
# Person                0
# Number             4516
# Case              39079
# PostN             44914
# PostN-weight      44918
# PostN-cat         44922
# Poss              45419
# PossPN            45421
# AdjPre                4
# AdjPre1           44089
# AdjPre2           45375
# AdjPost           45394
# AdjPost1          45394
# AdjPost2          45426
# AdjModStrength    45426
# Quant             45269
# QuantPos          45270
# PreN-other        45412
# PreN-weight       43956
# ClauseType        39092
# VerbPos           40251
# Func              39087
# Position          40285
# dtype: int64

# %% [markdown]
# This is looking fine, the crucial columns where there should be no NaN values are `Hit` and `incl`. `APC` looks plausible, we should double check that there are no NaN values there when `incl==1` (that's when `APC` will be needed for marking the target construction).

# %%
dwds.loc[(dwds.incl == 1) & dwds.APC.isna(),['Hit','APC']]
# Out:
# Empty DataFrame
# Columns: [Hit, APC]
# Index: []

# %% [markdown]
# There was one missing value here, fixed upstream!
#
# For reference, here's what was fixed:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hit</th>
#       <th>APC</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>17101</th>
#       <td>O du Sommertag über den Bergen, wie wunderschön bist du!</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Person
# Check values for Person and Number (though probably not used for training)

# %%
dwds.Person.unique()
# Out:
# array([1, 2, '1', '2', '2Hon', '3Hon'], dtype=object)

# %% [markdown]
# Unique values for person are consistent.

# %% [markdown]
# ### Number

# %%
dwds.Number.unique()
# Out:
# array(['sg', 'pl', nan, 'Sg', 'Pl'], dtype=object)

# %%
dwds.Number.value_counts()
# Out:
# Number
# pl    20578
# sg    20321
# Sg        6
# Pl        6
# Name: count, dtype: int64

# %% [markdown]
# Normalise `Pl` to `pl` and `Sg` to `sg`.

# %%
dwds.loc[dwds.Number.isin(['Sg','Pl']), 'Number'] = dwds.loc[dwds.Number.isin(['Sg','Pl']), 'Number'].str.lower()

# %%
dwds.Number.value_counts()
# Out:
# Number
# pl    20584
# sg    20327
# Name: count, dtype: int64

# %% [markdown]
# ### Case

# %%
dwds.Case.unique()
# Out:
# array([nan, 'nom', 'acc', 'dat', 'acc / dat', 'dat / acc'], dtype=object)

# %%
dwds.Case.value_counts()
# Out:
# Case
# nom          4788
# dat           926
# acc           632
# acc / dat       1
# dat / acc       1
# Name: count, dtype: int64

# %%
dwds.loc[dwds.Case.isin(['acc / dat', 'dat / acc']), ['Hit','APC','Case']]
# Out:
#                                                                                                                                                                                Hit  \
# ID
# 11502  S - so kränken brauchen Sie mir alten Mann doch nich.... Nee ... das können Sie mir glauben - leicht wird es einem ehrlichen Menschen nicht, einen Diebstahl einzugestehen.
# 11709                                                                                          Warum sin denn a einmal so niederträchtig und jrob zu mich armes Mächen, Frau John?
#
#                       APC       Case
# ID
# 11502      mir alten Mann  acc / dat
# 11709  mich armes Mädchen  dat / acc

# %% [markdown]
# Those markings are actually plausible (case expected in configuration is the first, morphological case occurring the second value; this is a dialectal feature). Leave this as is for now, we might not use the case marking in any case.

# %%
dwds.columns
dwds.rename(columns={'incl':'instance'},inplace=True)
dwds.instance = dwds.instance.astype(int)

# %%
dwds.isna().sum()
# Out:
# Search                0
# No.                   0
# Date                  0
# Genre                 0
# Bibl                  0
# ContextBefore       209
# Hit                   0
# ContextAfter        316
# instance              0
# APC               39038
# Pron              39019
# N                 39018
# Nlemma            39027
# doubled           45347
# comment           44738
# Nprops            44035
# GenderA           45164
# StrengthA         45258
# NumNDiff          45395
# Person                0
# Number             4516
# Case              39079
# PostN             44914
# PostN-weight      44918
# PostN-cat         44922
# Poss              45419
# PossPN            45421
# AdjPre                4
# AdjPre1           44089
# AdjPre2           45375
# AdjPost           45394
# AdjPost1          45394
# AdjPost2          45426
# AdjModStrength    45426
# Quant             45269
# QuantPos          45270
# PreN-other        45412
# PreN-weight       43956
# ClauseType        39092
# VerbPos           40251
# Func              39087
# Position          40285
# dtype: int64

# %%
# save a boiled-down version of the cleaned CSV
dwds[['ContextBefore','Hit','ContextAfter','instance','APC']].to_csv('../data/copyright/DWDS_APC_main_redux.csv')

# %% [markdown]
# Get another overview of the cleaned data

# %%
print(dwds.value_counts('instance'))
sns.countplot(dwds, x='instance')
plt.xlabel('Contains an APC');
# Out:
# instance
# 0    39239
# 1     6188
# Name: count, dtype: int64

# %%
persnumcount = dwds.groupby(['Person','Number','instance'])['Search'].count().reset_index().rename(columns={'Search':'Count'})

# %%
persnumcount
# Out:
#    Person Number  instance  Count
# 0       1     pl         0   9148
# 1       1     pl         1   3424
# 2       1     sg         0  14447
# 3       1     sg         1    327
# 4       2     sg         0   3568
# 5       2     sg         1   1756
# 6       1     pl         0   5099
# 7       1     pl         1    272
# 8       2     pl         0   2428
# 9       2     pl         1    200
# 10   2Hon     sg         0      1
# 11   2Hon     sg         1      1
# 12   3Hon     pl         0     11
# 13   3Hon     pl         1      2
# 14   3Hon     sg         0     22
# 15   3Hon     sg         1    205

# %%
sns.barplot(persnumcount.loc[persnumcount.instance==1],x='Person',y='Count',hue='Number',errorbar=None,estimator='sum');
